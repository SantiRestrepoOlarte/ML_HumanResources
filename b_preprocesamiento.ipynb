# %%
#Librerias

import pandas as pd
import numpy as np

# %% [markdown]
# ### **LECTURA DE DATOS**

# %%
df_general = pd.read_csv('data//general_data.csv')

# tamaño de dataframe general
df_general.shape
# Out:
# (8820, 24)

# %%
df_encuesta = pd.read_csv('data//employee_survey_data.csv')

# tamaño de dataframe encuesta
df_encuesta.shape
# Out:
# (8820, 5)

# %%
df_manager = pd.read_csv('data//manager_survey.csv')

# tamaño de dataframe manager
df_manager.shape
# Out:
# (8820, 4)

# %%
df_retiro= pd.read_csv('data//retirement_info.csv')

# tamaño de dataframe retirement
df_retiro.shape
# Out:
# (711, 5)

# %% [markdown]
# Respecto a la base de datos general, se puede observar que al analizarla hay algunas columnas que son candidatas a ser eliminadas.
# Columnas como Over18, StandardHours y EmployeeCount, al ser constantes no presentan comportamiento significativo.

# %%
df_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      8820 non-null   int64
#  1   BusinessTravel           8820 non-null   object
#  2   Department               8820 non-null   object
#  3   DistanceFromHome         8820 non-null   int64
#  4   Education                8820 non-null   int64
#  5   EducationField           8820 non-null   object
#  6   EmployeeCount            8820 non-null   int64
#  7   EmployeeID               8820 non-null   int64
#  8   Gender                   8820 non-null   object
#  9   JobLevel                 8820 non-null   int64
#  10  JobRole                  8820 non-null   object
#  11  MaritalStatus            8820 non-null   object
#  12  MonthlyIncome            8820 non-null   int64
#  13  NumCompaniesWorked       8782 non-null   float64
# ...

# %% [markdown]
# ### **UNIÓN DE TABLAS**

# %%
#Renombrar columnna de fecha que aparece como InfoDate a Year
df_general = df_general.rename(columns={'InfoDate': 'Year'})

# %%
#revision de columnas
df_general
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
#Renombrar columnna de fecha que aparece como DateSurvey a Year
df_encuesta = df_encuesta.rename(columns={'DateSurvey': 'Year'})

# %%
#Revision de columnas
df_encuesta
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 8815        4406                      4.0              1.0              3.0
# 8816        4407                      4.0              4.0              3.0
# 8817        4408                      1.0              3.0              3.0
# 8818        4409                      4.0              1.0              3.0
# 8819        4410                      1.0              3.0              NaN
#
#             Year
# 0     2015-12-31
# 1     2015-12-31
# ...

# %%
#Renombrar columnna de fecha que aparece como SurveyDate a Year
df_manager = df_manager.rename(columns={'SurveyDate': 'Year'})

# %%
#Revision de columnas
df_manager
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating        Year
# 0              1               3                  3  2015-12-31
# 1              2               2                  4  2015-12-31
# 2              3               3                  3  2015-12-31
# 3              4               2                  3  2015-12-31
# 4              5               3                  3  2015-12-31
# ...          ...             ...                ...         ...
# 8815        4406               3                  3  2016-12-31
# 8816        4407               2                  3  2016-12-31
# 8817        4408               3                  4  2016-12-31
# 8818        4409               2                  3  2016-12-31
# 8819        4410               4                  3  2016-12-31
#
# [8820 rows x 4 columns]

# %% [markdown]
# MERGED 1

# %% [markdown]
# En el primer merged de la base de datos se priorizó unir dos bases (General y Encuesta) que tuvieran la misma cantidad de observaciones (8820) para tener claro que el dataframe resultante debía tener 8820 de igual manera, solamente aumentando la cantidad de columnas. La union se realizo con EmployeeID y con Year para garantizar que sean los empleados del mismo año en y el mismo ID.

# %%
#Union de lo dataframes
df_merged1 = pd.merge(df_general, df_encuesta, on=['EmployeeID', 'Year'], how='outer')

# %%
#Revision de columnas
df_merged1
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %% [markdown]
# MERGED 2

# %% [markdown]
# En el segundo merged se decide unirlo con la base de datos de manager ya que tambien cuenta con 8820 observaciones y permite una revisión fácil para confirmar que no presente problemas. Además también se vuelven a unir según las columnas de EmployeeID y Year.

# %%
#creacion del segundo merged donde ya se han consolidado 3 bases de datos 
df_merged2 = pd.merge(df_merged1,df_manager, on=['EmployeeID','Year'],how='outer')

# %%
#Revision del segundo merged
df_merged2
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
#Se renombra la columna EmployeeID a Col_ID y se pone en la primera columna del dataframe para facilitar la revisión 

col_ID = df_merged2.pop('EmployeeID')

df_merged2.insert(0, 'EmployeeID', col_ID)

# %%
#Se renombra la columna Year a Col_Year y se pone en la segunda columna del dataframe para facilitar la revisión 

col_Year = df_merged2.pop('Year')

df_merged2.insert(1, 'Year', col_Year)

# %%
#Revision del segundo merged
df_merged2
# Out:
#       EmployeeID        Year  Age     BusinessTravel              Department  \
# 0              1  2015-12-31   51      Travel_Rarely                   Sales
# 1              2  2015-12-31   31  Travel_Frequently  Research & Development
# 2              3  2015-12-31   32  Travel_Frequently  Research & Development
# 3              4  2015-12-31   38         Non-Travel  Research & Development
# 4              5  2015-12-31   32      Travel_Rarely  Research & Development
# ...          ...         ...  ...                ...                     ...
# 8815        4406  2016-12-31   42      Travel_Rarely  Research & Development
# 8816        4407  2016-12-31   29      Travel_Rarely  Research & Development
# 8817        4408  2016-12-31   25      Travel_Rarely  Research & Development
# 8818        4409  2016-12-31   42      Travel_Rarely                   Sales
# 8819        4410  2016-12-31   40      Travel_Rarely  Research & Development
#
# ...

# %%
'''''
Se utiliza query para revisar los empleaados que se retiraron en el 2015 no deberían estar en 
la base de datos del 2016 porque ellos estarían en el 2014 (la cual no se tiene)
'''
df_merged2.query("EmployeeID == 2")
# Out:
#    EmployeeID        Year  Age     BusinessTravel              Department  \
# 1           2  2015-12-31   31  Travel_Frequently  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 1                10          1  Life Sciences              1  Female  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# 1                6.0                     3              5
#
#    YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 1                        1                     4                     3.0
#
#    JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 1              2.0              4.0               2                  4
#
# [1 rows x 29 columns]

# %%
#Cambiar la columna Year a tipo fecha (date time) y se reemplazan los valores de datetime en la columna Year otra vez pero con el nuevo formato
df_merged2['Year'] = pd.to_datetime(df_merged2['Year'])

# %%
#Del formato anterior extraemos solo el año ya que es la variable que nos importa
df_merged2['Year'] = df_merged2['Year'].dt.year

# %%
#Revision de los cambios efectuados
df_merged2
# Out:
#       EmployeeID  Year  Age     BusinessTravel              Department  \
# 0              1  2015   51      Travel_Rarely                   Sales
# 1              2  2015   31  Travel_Frequently  Research & Development
# 2              3  2015   32  Travel_Frequently  Research & Development
# 3              4  2015   38         Non-Travel  Research & Development
# 4              5  2015   32      Travel_Rarely  Research & Development
# ...          ...   ...  ...                ...                     ...
# 8815        4406  2016   42      Travel_Rarely  Research & Development
# 8816        4407  2016   29      Travel_Rarely  Research & Development
# 8817        4408  2016   25      Travel_Rarely  Research & Development
# 8818        4409  2016   42      Travel_Rarely                   Sales
# 8819        4410  2016   40      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# ...

# %% [markdown]
# MERGED 3

# %%
df_retiro
# Out:
#      EmployeeID Attrition retirementDate retirementType resignationReason
# 0             2       Yes     2016-10-15    Resignation            Others
# 1             7       Yes     2016-07-20    Resignation            Stress
# 2            14       Yes     2016-11-08    Resignation            Others
# 3            29       Yes     2016-10-15    Resignation            Others
# 4            31       Yes     2016-02-08    Resignation            Salary
# ..          ...       ...            ...            ...               ...
# 706        4382       Yes     2015-04-18    Resignation            Salary
# 707        4387       Yes     2015-09-16    Resignation            Others
# 708        4389       Yes     2015-05-24    Resignation            Others
# 709        4392       Yes     2015-02-26          Fired               NaN
# 710        4403       Yes     2015-01-26    Resignation            Stress
#
# [711 rows x 5 columns]

# %%
#Se convierte la columna RTYear a tipo fecha (date time)
df_retiro['retirementDate'] = pd.to_datetime(df_retiro['retirementDate'])

# %%
#Del formato date time extraemos solo el año y la metemos en la nueva columna llamada Year
df_retiro['retirementDate'] = df_retiro['retirementDate'].dt.year

# %%
df_retiro
# Out:
#      EmployeeID Attrition  retirementDate retirementType resignationReason
# 0             2       Yes            2016    Resignation            Others
# 1             7       Yes            2016    Resignation            Stress
# 2            14       Yes            2016    Resignation            Others
# 3            29       Yes            2016    Resignation            Others
# 4            31       Yes            2016    Resignation            Salary
# ..          ...       ...             ...            ...               ...
# 706        4382       Yes            2015    Resignation            Salary
# 707        4387       Yes            2015    Resignation            Others
# 708        4389       Yes            2015    Resignation            Others
# 709        4392       Yes            2015          Fired               NaN
# 710        4403       Yes            2015    Resignation            Stress
#
# [711 rows x 5 columns]

# %%
#Filtramos solamente a un año (el 2015 no nos interesa de momento) y posteriormente será eliminado 
df_2015= df_retiro[df_retiro['retirementDate'] == 2015]

# %%
#Se crea una copia del dataframe de retiro y a esta nueva copia se le eliminaron los datos del 2015
df_retiro = df_retiro.drop(df_2015.index)

# %%
df_retiro
# Out:
#      EmployeeID Attrition  retirementDate retirementType resignationReason
# 0             2       Yes            2016    Resignation            Others
# 1             7       Yes            2016    Resignation            Stress
# 2            14       Yes            2016    Resignation            Others
# 3            29       Yes            2016    Resignation            Others
# 4            31       Yes            2016    Resignation            Salary
# ..          ...       ...             ...            ...               ...
# 645        3973       Yes            2016    Resignation            Others
# 646        3974       Yes            2016    Resignation            Others
# 647        3980       Yes            2016    Resignation            Others
# 648        3981       Yes            2016    Resignation            Others
# 649        3995       Yes            2016    Resignation            Others
#
# [650 rows x 5 columns]

# %%
# Eliminación de la fecha de retiro ya que no se tendrá en cuenta
df_retiro.drop('retirementDate', axis=1, inplace=True)

# %%
df_retiro
# Out:
#      EmployeeID Attrition retirementType resignationReason
# 0             2       Yes    Resignation            Others
# 1             7       Yes    Resignation            Stress
# 2            14       Yes    Resignation            Others
# 3            29       Yes    Resignation            Others
# 4            31       Yes    Resignation            Salary
# ..          ...       ...            ...               ...
# 645        3973       Yes    Resignation            Others
# 646        3974       Yes    Resignation            Others
# 647        3980       Yes    Resignation            Others
# 648        3981       Yes    Resignation            Others
# 649        3995       Yes    Resignation            Others
#
# [650 rows x 4 columns]

# %%
#Creacion del tercer merged, en el cual ya se tienen los datos que nos interesa del dataframe retiro. Adicionalmente se unen de acuerdo a EmployeeID
df_merged3 = pd.merge(df_merged2,df_retiro, on=['EmployeeID'],how='outer')

# %%
#DATAFRAME FINAL
df_merged3
# Out:
#       EmployeeID  Year  Age     BusinessTravel              Department  \
# 0              1  2015   51      Travel_Rarely                   Sales
# 1              1  2016   51      Travel_Rarely                   Sales
# 2              2  2015   31  Travel_Frequently  Research & Development
# 3              3  2015   32  Travel_Frequently  Research & Development
# 4              3  2016   32  Travel_Frequently  Research & Development
# ...          ...   ...  ...                ...                     ...
# 8815        8383  2016   34  Travel_Frequently  Research & Development
# 8816        8384  2016   37      Travel_Rarely  Research & Development
# 8817        8390  2016   26      Travel_Rarely         Human Resources
# 8818        8391  2016   46      Travel_Rarely  Research & Development
# 8819        8405  2016   31      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  Gender  \
# ...

# %% [markdown]
# Finalmente, la base de datos consolidada es *'df_merged3'* la cual contiene todas las tablas, y a partir de esta se trabajará (se realizará la exploración de los datos y se alistará para el montaje de modelos)

# %%
# Visualizacion de los empleados que se retiraron
df_merged3[df_merged3['Attrition']=='Yes']
# Out:
#       EmployeeID  Year  Age     BusinessTravel              Department  \
# 2              2  2015   31  Travel_Frequently  Research & Development
# 11             7  2015   28      Travel_Rarely  Research & Development
# 24            14  2015   47         Non-Travel  Research & Development
# 53            29  2015   44  Travel_Frequently  Research & Development
# 56            31  2015   26      Travel_Rarely  Research & Development
# ...          ...   ...  ...                ...                     ...
# 7299        3973  2015   34  Travel_Frequently  Research & Development
# 7300        3974  2015   37      Travel_Rarely  Research & Development
# 7311        3980  2015   26      Travel_Rarely         Human Resources
# 7312        3981  2015   46      Travel_Rarely  Research & Development
# 7339        3995  2015   31      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  Gender  \
# ...

# %% [markdown]
# ### **IDENTIFICACIÓN E IMPUTACIÓN DE NULOS**

# %%
# Columnas que contienen valores nulos
columns_with_nulls = df_merged3.columns[df_merged3.isnull().any()]
columns_with_nulls
# Out:
# Index(['NumCompaniesWorked', 'TotalWorkingYears', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'WorkLifeBalance', 'Attrition', 'retirementType',
#        'resignationReason'],
#       dtype='object')

# %%
df_merged3['WorkLifeBalance'].value_counts()
# Out:
# 3.0    5320
# 2.0    2038
# 4.0     908
# 1.0     478
# Name: WorkLifeBalance, dtype: int64

# %% [markdown]
# Se identifica que los datos nulos de algunas variables pueden ser reemplazadas con la mediana: 'NumCompaniesWorked', 'TotalWorkingYears', 'EnvironmentSatisfaction', 'JobSatisfaction' y 'WorkLifeBalance'.

# %%
var = ["NumCompaniesWorked", "TotalWorkingYears", "EnvironmentSatisfaction", "JobSatisfaction", "WorkLifeBalance"] #Definir las variables a tratar con la mediana

#Se utiliza una función para calcular la mediana para cada una de las variables seleccionadas anteriormente.

def imputar_mediana(df, columns):
    for col in columns:
        median_value = df[col].median() #Calcular la mediana
        df[col] = df[col].apply(lambda x: x if not pd.isnull(x) else int(median_value))
    return df

df_merged3 = imputar_mediana(df_merged3, var)

# %% [markdown]
# Y en el caso de las variables restantes (relacionadas con los datos de retiros) se entiende que las observaciones con datos nulos son los empleados que no se retiran. Por ende, la imputación de dichas datos debe ser por 'No aplica' o por valores de ese estilo.

# %%
# En el caso de 'Attrition' se reemplaza los nulos por 'No' dado que representa los empleados que no se retiran
df_merged3['Attrition'] = df_merged3['Attrition'].fillna('No')

# %%
# Además, con el objetivo de convertir la variable 'Attrition' en la variable objetivo más adelante, se reempaza 'Yes' por 1 y 'No' por 0 
df_merged3['Attrition'] = df_merged3['Attrition'].replace({'Yes': 1, 'No': 0})

# %%
# En el caso de las variables restantes ('retirementType', 'resignationReason') se reemplaza los nulos por 'Not Applicable'
df_merged3['retirementType'] = df_merged3['retirementType'].fillna('Not Applicable')
df_merged3['resignationReason'] = df_merged3['resignationReason'].fillna('Not Applicable')

# %%
df_merged3.columns
# Out:
# Index(['EmployeeID', 'Year', 'Age', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating', 'Attrition', 'retirementType',
#        'resignationReason'],
#       dtype='object')

# %%
df_merged3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8820 entries, 0 to 8819
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               8820 non-null   int64
#  1   Year                     8820 non-null   int64
#  2   Age                      8820 non-null   int64
#  3   BusinessTravel           8820 non-null   object
#  4   Department               8820 non-null   object
#  5   DistanceFromHome         8820 non-null   int64
#  6   Education                8820 non-null   int64
#  7   EducationField           8820 non-null   object
#  8   EmployeeCount            8820 non-null   int64
#  9   Gender                   8820 non-null   object
#  10  JobLevel                 8820 non-null   int64
#  11  JobRole                  8820 non-null   object
#  12  MaritalStatus            8820 non-null   object
#  13  MonthlyIncome            8820 non-null   int64
# ...

# %%
# Se realiza el cambio de tipología de algunas variables
def convertir_int(df, columns):
    for col in columns:
        df[col] = df[col].astype(int)
    return df

df_merged3 = convertir_int(df_merged3, var)

# %%
df_merged3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8820 entries, 0 to 8819
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               8820 non-null   int64
#  1   Year                     8820 non-null   int64
#  2   Age                      8820 non-null   int64
#  3   BusinessTravel           8820 non-null   object
#  4   Department               8820 non-null   object
#  5   DistanceFromHome         8820 non-null   int64
#  6   Education                8820 non-null   int64
#  7   EducationField           8820 non-null   object
#  8   EmployeeCount            8820 non-null   int64
#  9   Gender                   8820 non-null   object
#  10  JobLevel                 8820 non-null   int64
#  11  JobRole                  8820 non-null   object
#  12  MaritalStatus            8820 non-null   object
#  13  MonthlyIncome            8820 non-null   int64
# ...

# %%
df_merged3.head(8)
# Out:
#    EmployeeID  Year  Age     BusinessTravel              Department  \
# 0           1  2015   51      Travel_Rarely                   Sales
# 1           1  2016   51      Travel_Rarely                   Sales
# 2           2  2015   31  Travel_Frequently  Research & Development
# 3           3  2015   32  Travel_Frequently  Research & Development
# 4           3  2016   32  Travel_Frequently  Research & Development
# 5           4  2015   38         Non-Travel  Research & Development
# 6           4  2016   38         Non-Travel  Research & Development
# 7           5  2015   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                 6          2  Life Sciences              1  Female  ...
# 2                10          1  Life Sciences              1  Female  ...
# ...

# %%
df_merged3 = df_merged3.sort_values(by=['Year', 'EmployeeID']) #Ordenar y filtrar la base de datos

# %%
df_merged3['JobRole'].value_counts()
# Out:
# Sales Executive              1956
# Research Scientist           1752
# Laboratory Technician        1554
# Manufacturing Director        870
# Healthcare Representative     786
# Manager                       612
# Sales Representative          498
# Research Director             480
# Human Resources               312
# Name: JobRole, dtype: int64

# %% [markdown]
# ### Datos necesarios para dashboard de exploración

# %% [markdown]
# A continuación se realizan algunos filtros necesarios para consolidar algunos datos a utilizar en la visualización de la exploración, pero su única finalidad es esa, no se utilizan en otro procedimiento.

# %%
# Datos completos de solo los empleados que se retiran a usar en dashboard
df_only_retired = df_merged3[df_merged3['Attrition']==1]
df_only_retired
# Out:
#       EmployeeID  Year  Age     BusinessTravel              Department  \
# 2              2  2015   31  Travel_Frequently  Research & Development
# 11             7  2015   28      Travel_Rarely  Research & Development
# 24            14  2015   47         Non-Travel  Research & Development
# 53            29  2015   44  Travel_Frequently  Research & Development
# 56            31  2015   26      Travel_Rarely  Research & Development
# ...          ...   ...  ...                ...                     ...
# 7299        3973  2015   34  Travel_Frequently  Research & Development
# 7300        3974  2015   37      Travel_Rarely  Research & Development
# 7311        3980  2015   26      Travel_Rarely         Human Resources
# 7312        3981  2015   46      Travel_Rarely  Research & Development
# 7339        3995  2015   31      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  Gender  \
# ...

# %%
#df_only_retired.to_csv('df_only_retired.csv', index=False)

# %%
# Moviendo la columna 'Attrition' 2 posiciones a la derecha
cols = df_merged3.columns.tolist()
cols.insert(cols.index('Attrition')+2, cols.pop(cols.index('Attrition')))
df_merged3 = df_merged3[cols]

# %%
df_merged3.head(8)
# Out:
#     EmployeeID  Year  Age     BusinessTravel              Department  \
# 0            1  2015   51      Travel_Rarely                   Sales
# 2            2  2015   31  Travel_Frequently  Research & Development
# 3            3  2015   32  Travel_Frequently  Research & Development
# 5            4  2015   38         Non-Travel  Research & Development
# 7            5  2015   32      Travel_Rarely  Research & Development
# 9            6  2015   46      Travel_Rarely  Research & Development
# 11           7  2015   28      Travel_Rarely  Research & Development
# 12           8  2015   29      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                  6          2  Life Sciences              1  Female  ...
# 2                 10          1  Life Sciences              1  Female  ...
# 3                 17          4          Other              1    Male  ...
# ...

# %%
#df_entire_data.to_csv('entire_data.csv', index=False)

# %% [markdown]
# Hasta acá llegan los filtros de datos para visualización. Ahora, se continua con el preprocesamiento restante.

# %% [markdown]
# ### Continuación del preprocesamiento

# %%
df_merged3.head()
# Out:
#    EmployeeID  Year  Age     BusinessTravel              Department  \
# 0           1  2015   51      Travel_Rarely                   Sales
# 2           2  2015   31  Travel_Frequently  Research & Development
# 3           3  2015   32  Travel_Frequently  Research & Development
# 5           4  2015   38         Non-Travel  Research & Development
# 7           5  2015   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 2                10          1  Life Sciences              1  Female  ...
# 3                17          4          Other              1    Male  ...
# 5                 2          5  Life Sciences              1    Male  ...
# 7                10          1        Medical              1    Male  ...
#
#    YearsSinceLastPromotion YearsWithCurrManager EnvironmentSatisfaction  \
# ...

# %% [markdown]
# ### **ELIMINACIÓN DE VARIABLES**

# %%
df_merged3['Year'].value_counts()
# Out:
# 2015    4410
# 2016    4410
# Name: Year, dtype: int64

# %%
df_merged3[df_merged3['EmployeeID']==4410]
# Out:
#       EmployeeID  Year  Age BusinessTravel              Department  \
# 8168        4410  2015   40  Travel_Rarely  Research & Development
# 8169        4410  2016   40  Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount Gender  ...  \
# 8168                28          3        Medical              1   Male  ...
# 8169                28          3        Medical              1   Male  ...
#
#       YearsSinceLastPromotion YearsWithCurrManager EnvironmentSatisfaction  \
# 8168                        3                    9                       1
# 8169                        3                    9                       1
#
#       JobSatisfaction  WorkLifeBalance JobInvolvement  PerformanceRating  \
# 8168                3                3              4                  3
# 8169                3                3              4                  3
#
#       retirementType  resignationReason  Attrition
# ...

# %%
df_merged3.columns
# Out:
# Index(['EmployeeID', 'Year', 'Age', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating', 'retirementType',
#        'resignationReason', 'Attrition'],
#       dtype='object')

# %%
df_merged3['EmployeeCount'].value_counts()
# Out:
# 1    8820
# Name: EmployeeCount, dtype: int64

# %%
df_merged3['Over18'].value_counts()
# Out:
# Y    8820
# Name: Over18, dtype: int64

# %%
df_merged3['StandardHours'].value_counts()
# Out:
# 8    8820
# Name: StandardHours, dtype: int64

# %% [markdown]
# Se identifica que las variables *'EmployeeCount'*, *'Over18'* y *'StandardHours'* solo cuentan con un valor, por ende se decide eliminarlas del dataframe.

# %%
# Eliminación de columnas
df_merged3 = df_merged3.drop('EmployeeCount', axis=1)
df_merged3 = df_merged3.drop('Over18', axis=1)
df_merged3 = df_merged3.drop('StandardHours', axis=1)

# %%
df_merged3.head()
# Out:
#    EmployeeID  Year  Age     BusinessTravel              Department  \
# 0           1  2015   51      Travel_Rarely                   Sales
# 2           2  2015   31  Travel_Frequently  Research & Development
# 3           3  2015   32  Travel_Frequently  Research & Development
# 5           4  2015   38         Non-Travel  Research & Development
# 7           5  2015   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  Gender  JobLevel  ...  \
# 0                 6          2  Life Sciences  Female         1  ...
# 2                10          1  Life Sciences  Female         1  ...
# 3                17          4          Other    Male         4  ...
# 5                 2          5  Life Sciences    Male         3  ...
# 7                10          1        Medical    Male         1  ...
#
#   YearsSinceLastPromotion YearsWithCurrManager  EnvironmentSatisfaction  \
# ...

# %%
df_merged3.columns
# Out:
# Index(['EmployeeID', 'Year', 'Age', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance', 'JobInvolvement', 'PerformanceRating',
#        'retirementType', 'resignationReason', 'Attrition'],
#       dtype='object')

# %%
df_merged3['JobRole'].value_counts()
# Out:
# Sales Executive              1956
# Research Scientist           1752
# Laboratory Technician        1554
# Manufacturing Director        870
# Healthcare Representative     786
# Manager                       612
# Sales Representative          498
# Research Director             480
# Human Resources               312
# Name: JobRole, dtype: int64

# %%
df_merged3['Department'].value_counts()
# Out:
# Research & Development    5766
# Sales                     2676
# Human Resources            378
# Name: Department, dtype: int64

# %% [markdown]
# Por otro lado, se identifica que la variable *'JobRole'* y *'Department'* ofrecen información similar. Así mismo, *'JobRole* presenta 9 categorías diferentes, lo que aumentaría la dimensión del dataframe una vez se lleve a formato dummies, por ende, se decide eliminar la variabale *'JobRole'* del dataframe.

# %%
df_merged3 = df_merged3.drop('JobRole', axis=1)

# %%
df_merged3.head()
# Out:
#    EmployeeID  Year  Age     BusinessTravel              Department  \
# 0           1  2015   51      Travel_Rarely                   Sales
# 2           2  2015   31  Travel_Frequently  Research & Development
# 3           3  2015   32  Travel_Frequently  Research & Development
# 5           4  2015   38         Non-Travel  Research & Development
# 7           5  2015   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  Gender  JobLevel  ...  \
# 0                 6          2  Life Sciences  Female         1  ...
# 2                10          1  Life Sciences  Female         1  ...
# 3                17          4          Other    Male         4  ...
# 5                 2          5  Life Sciences    Male         3  ...
# 7                10          1        Medical    Male         1  ...
#
#   YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# ...

# %%
df_agrupado = df_merged3.groupby('Attrition')['Gender'].value_counts()
df_agrupado
# Out:
# Attrition  Gender
# 0          Male      4886
#            Female    3284
# 1          Male       406
#            Female     244
# Name: Gender, dtype: int64

# %% [markdown]
# Se evidencia que en el caso de la variable *'Gender'*, la proporción de hombres y mujeres es proporcional independientemente de la variable objetivo, por ende, esta variable no ofrece explicabilidad relevante, y por eso se elimina.

# %%
df_merged3 = df_merged3.drop('Gender', axis=1)

# %%
df_agrupado2 = df_merged3.groupby('Attrition')['BusinessTravel'].value_counts()
df_agrupado2
# Out:
# Attrition  BusinessTravel
# 0          Travel_Rarely        5836
#            Travel_Frequently    1469
#            Non-Travel            865
# 1          Travel_Rarely         422
#            Travel_Frequently     193
#            Non-Travel             35
# Name: BusinessTravel, dtype: int64

# %%
df_merged3['PerformanceRating'].value_counts()
# Out:
# 3    7464
# 4    1356
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# Finalmente, se encuentra que la variable *'PerformanceRating'* solo posee 2 valores (3 y 4), lo que básicamente no nos arroja información relevante. Además, los 2 valores son cercanos, y por ende, no permite realizar una diferenciación útil. Se decide eliminarlas.

# %%
df_merged3 = df_merged3.drop('PerformanceRating', axis=1)

# %% [markdown]
# Para finalizar, se observa entonces que el dataframe final a utilizar en la exploración de datos posee 27 columnas (26 variables explicativas y su respectiva variable objetivo). Este dataframe se exporta a la carpeta 'data' con la finalidad de poderla leer en los archivos siguientes.

# %%
df_merged3.head()
# Out:
#    EmployeeID  Year  Age     BusinessTravel              Department  \
# 0           1  2015   51      Travel_Rarely                   Sales
# 2           2  2015   31  Travel_Frequently  Research & Development
# 3           3  2015   32  Travel_Frequently  Research & Development
# 5           4  2015   38         Non-Travel  Research & Development
# 7           5  2015   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  JobLevel MaritalStatus  ...  \
# 0                 6          2  Life Sciences         1       Married  ...
# 2                10          1  Life Sciences         1        Single  ...
# 3                17          4          Other         4       Married  ...
# 5                 2          5  Life Sciences         3       Married  ...
# 7                10          1        Medical         1        Single  ...
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  \
# ...

# %%
# Exportación del dataframe para su posterior uso
df_merged3.to_csv('data/df_employees.csv', index=False)
